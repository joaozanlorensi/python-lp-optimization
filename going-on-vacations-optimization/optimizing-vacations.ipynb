# %%
from pulp import *
import pandas as pd

# %%
total_vacations_days = 22

# %%
prob = LpProblem("going_on_vacations", LpMinimize)

# %%
df = pd.read_csv('./trips.csv')

# %%
df.head()
# Out:
#   destination  duration_days  cost_usd
# 0       Tokyo              4     18370
# 1     Jakarta              7     22750
# 2       Delhi              1      4078
# 3      Mumbai              7     15068
# 4      Manila              2      9663

# %%
# Creates a list with our variables, in this case the destinations
destinations = list(df['destination'])
# Creates two dictionaries with the parameters durations and costs
durations = dict(zip(destinations, df['duration_days']))
costs = dict(zip(destinations, df['cost_usd']))

# %%
durations
# Out:
# {'Tokyo': 4,
#  'Jakarta': 7,
#  'Delhi': 1,
#  'Mumbai': 7,
#  'Manila': 2,
#  'Shanghai': 7,
#  'Sao Paulo': 6,
#  'Seoul': 5,
#  'Mexico City': 15,
#  'Guangzhou': 2,
#  'Beijing': 12,
#  'Cairo': 6,
#  'New York': 3,
#  'Kolkata': 5,
#  'Moscow': 10,
#  'Bangkok': 7,
#  'Buenos Aires': 5,
#  'Shenzhen': 6,
#  'Dhaka': 3,
#  'Lagos': 13,
#  'Istanbul': 13,
#  'Osaka': 6,
#  'Karachi': 14,
#  'Bangalore': 1,
#  'Tehran': 4,
#  'Kinshasa': 10,
#  'Ho Chi Minh City': 6,
#  'Los Angeles': 12,
#  'Rio de Janeiro': 4,
#  'Nanyang': 11,
#  'Baoding': 15,
#  'Chennai': 12,
#  'Chengdu': 15,
#  'Lahore': 11,
#  'Paris': 3,
#  'London': 6,
#  'Linyi': 11,
#  'Tianjin': 15,
#  'Shijiazhuang': 12,
#  'Zhoukou': 1,
#  'Lima': 3,
#  'Hyderabad': 6,
#  'Handan': 1,
#  'Bogota': 4,
#  'Weifang': 1,
#  'Nagoya': 1,
#  'Wuhan': 2,
#  'Heze': 5,
#  'Ganzhou': 2,
#  'Tongshan': 10,
#  'Chicago': 3,
#  'Luanda': 3,
#  'Changsha': 7,
#  'Fuyang': 7,
#  'Kuala Lumpur': 1,
#  'Jining': 14,
#  'Dongguan': 11,
#  'Jinan': 6,
#  'Foshan': 6,
#  'Hanoi': 3,
#  'Pune': 9,
#  'Chongqing': 13,
#  'Changchun': 11,
#  'Zhumadian': 14,
#  'Ningbo': 5,
#  'Cangzhou': 8,
#  'Nanjing': 2,
#  'Hefei': 11,
#  'Ahmedabad': 2,
#  'Hong Kong': 13,
#  'Zhanjiang': 4,
#  'Shaoyang': 4,
#  'Hengyang': 3,
#  'Khartoum': 4,
#  'Nantong': 9,
#  'Yancheng': 8,
#  'Nanning': 14,
#  "Xi'an": 1,
#  'Shenyang': 14,
#  'Tangshan': 10,
#  'Santiago': 14,
#  'Zhengzhou': 8,
#  'Shangqiu': 1,
#  'Yantai': 2,
#  'Riyadh': 12,
#  'Dar es Salaam': 15,
#  'Xinyang': 3,
#  'Shangrao': 13,
#  'Luoyang': 10,
#  'Bijie': 5,
#  'Quanzhou': 10,
#  'Hangzhou': 3,
#  'Miami': 1,
#  'Huanggang': 12,
#  'Maoming': 1,
#  'Kunming': 8,
#  'Nanchong': 5,
#  'Zunyi': 10,
#  'Jieyang': 5,
#  "Lu'an": 7,
#  'Yichun': 9,
#  'Madrid': 3,
#  'Changde': 11,
#  'Taizhou': 2,
#  'Liaocheng': 7,
#  'Qujing': 4,
#  'Surat': 15,
#  'Baghdad': 7,
#  'Qingdao': 11,
#  'Singapore': 13,
#  'Dallas': 7,
#  'Dazhou': 13,
#  'Suzhou': 6,
#  'Xiangyang': 15,
#  'Philadelphia': 6,
#  'Giza': 1,
#  'Nairobi': 1,
#  'Nangandao': 1,
#  'Ankara': 4,
#  "Tai'an": 2,
#  'Yulin': 7,
#  'Dezhou': 6,
#  'Houston': 12,
#  'Atlanta': 12,
#  'Yongzhou': 8,
#  'Rangoon': 9,
#  'Toronto': 4,
#  'Suihua': 8,
#  'Washington': 3,
#  'Qiqihar': 1,
#  'Jinhua': 8,
#  'Saint Petersburg': 2,
#  'Shantou': 4,
#  'Sydney': 14,
#  'Weinan': 2,
#  'Suqian': 3,
#  'Guadalajara': 12,
#  'Fuzhou': 8,
#  'Zhaotong': 7,
#  'Pudong': 9,
#  'Belo Horizonte': 2,
#  'Zhangzhou': 7,
#  'Bozhou': 10,
#  'Melbourne': 13,
#  'Nanchang': 6,
#  'Xianyang': 14,
#  'Surabaya': 15,
#  'Abidjan': 8,
#  'Huaihua': 1,
#  "Ji'an": 2,
#  'Mianyang': 2,
#  'Xiaoganzhan': 12,
#  'Shaoxing': 12,
#  'Alexandria': 5,
#  'Yuncheng': 11,
#  'Pingdingshan': 9,
#  'Huizhou': 7,
#  "Huai'an": 4,
#  'Xinpu': 8,
#  'Chenzhou': 3,
#  'Guilin': 4,
#  'Jiujiang': 3,
#  'Anqing': 3,
#  'Boston': 11,
#  'Huanglongsi': 2,
#  'Jiangmen': 6,
#  'Changzhou': 6,
#  'Barcelona': 9,
#  'Wuxi': 5,
#  'Zibo': 7,
#  'Jiaxing': 1,
#  'Dalian': 1,
#  'Hengshui': 2,
#  'Harbin': 13,
#  'Yangzhou': 3,
#  'Yibin': 7,
#  'Johannesburg': 10,
#  'Yiyang': 1,
#  'Meizhou': 9,
#  'Chifeng': 8,
#  'Casablanca': 5,
#  'Guiyang': 12,
#  'Langfang': 10,
#  'Zhangjiakou': 7,
#  'Izmir': 12,
#  'Linfen': 9,
#  'Wenzhou': 11,
#  'Monterrey': 15,
#  'Luzhou': 3,
#  'Jiangguanchi': 6,
#  'Neijiang': 3,
#  'Phoenix': 11,
#  'Yanjiang': 13,
#  'Zhaoqing': 14,
#  'Xiaoxita': 5,
#  'Guigang': 8,
#  'Xiamen': 10,
#  'Chuzhou': 15,
#  'Zhuzhou': 4,
#  'Amman': 14,
#  'Jeddah': 2,
#  'Loudi': 7,
#  'Deyang': 2,
#  'Qingyuan': 4,
#  'Wuhu': 11,
#  'Hechi': 14,
#  'Seattle': 6,
#  'Binzhou': 6,
#  'Yokohama': 9,
#  'Liuzhou': 6,
#  'Baojishi': 2,
#  "Guang'an": 10,
#  'Hanzhong': 12,
#  'Kabul': 15,
#  'Zaozhuang': 5,
#  'Berlin': 6,
#  'Anshan': 11,
#  'Lanzhou': 11,
#  'Chengde': 13,
#  'San Francisco': 1,
#  'Puyang': 13,
#  'Suining': 5,
#  'Jiaozuo': 13,
#  'Bengbu': 5,
#  'Montreal': 4,
#  'Detroit': 6,
#  'Baicheng': 4,
#  'Busan': 11,
#  'Algiers': 1,
#  'Qincheng': 8,
#  'Taiyuan': 8,
#  'Shiyan': 1,
#  'Lucknow': 8,
#  'Chaoyang': 7,
#  'Leshan': 4,
#  'Yulinshi': 13,
#  'Siping': 2,
#  'Zhongshan': 12,
#  'Changzhi': 13,
#  'San Diego': 1,
#  'Faisalabad': 12,
#  'Santa Cruz': 3,
#  'Qinhuangdao': 10,
#  'Bazhou': 11,
#  'Zhenjiang': 4,
#  'Urumqi': 1,
#  'Tongliao': 4,
#  'Heyuan': 7,
#  'Tongren': 8,
#  'Qinzhou': 5,
#  'Jaipur': 4,
#  'Xinzhou': 8,
#  'Addis Ababa': 5,
#  'Meishan': 1,
#  'Brasilia': 4,
#  'Mashhad': 12,
#  'Jinzhou': 12,
#  'Tieling': 9,
#  'Shaoguan': 9,
#  'Kuwait City': 9,
#  'Shanwei': 14,
#  'Minneapolis': 6,
#  'Kyiv': 3,
#  'Sanaa': 15,
#  'Quezon City': 9,
#  'Dingxi': 6,
#  'Incheon': 2,
#  'Bursa': 10,
#  'Ningde': 1,
#  'Tampa': 5,
#  'Daqing': 7,
#  'Birmingham': 12,
#  'Putian': 15,
#  'Huzhou': 12,
#  'Salvador': 12,
#  'Wuzhou': 2,
#  'Xiangtan': 3,
#  'Denver': 3,
#  'Rome': 1,
#  'La Paz': 8,
#  'Pyongyang': 2,
#  'Kano': 10,
#  'Taichung': 7,
#  'Omdurman': 6,
#  'Zigong': 8,
#  'Mudanjiang': 8,
#  'Huludao': 9,
#  'Kaohsiung': 3,
#  'Guayaquil': 8,
#  'Rizhao': 4,
#  'Manchester': 15,
#  'Cawnpore': 8,
#  'Baotou': 7,
#  'Taipei': 2,
#  'Nanping': 1,
#  'Chaozhou': 7,
#  'Longyan': 6,
#  'Ibadan': 6,
#  'Hohhot': 8,
#  'Antananarivo': 8,
#  'Longba': 14,
#  'Weihai': 3,
#  'Chattogram': 10,
#  'Santo Domingo': 1,
#  'Xuanzhou': 8,
#  'Sanming': 2,
#  'Brooklyn': 7,
#  'Yangjiang': 8,
#  'Medellin': 7,
#  'Yunfu': 1,
#  'Brisbane': 4,
#  'Baoshan': 8,
#  'Dubai': 6,
#  'Luohe': 2,
#  'Qinbaling': 10,
#  'Mirzapur': 13,
#  'Guangyuan': 3,
#  'Cali': 8,
#  'Huangshi': 3,
#  'Daegu': 3,
#  'Fortaleza': 10,
#  'Guatemala City': 15,
#  'Yaounde': 2,
#  'Douala': 4,
#  'Jilin': 6,
#  'Lianshan': 15,
#  'Lincang': 8,
#  'Antalya': 5,
#  'Tashkent': 7,
#  'Bandung': 9,
#  'Nagpur': 7,
#  'Huainan': 12,
#  'Dandong': 6,
#  'Shangzhou': 9,
#  'Bekasi': 4,
#  'Ghaziabad': 1,
#  'Tijuana': 2,
#  'Jiamusi': 5,
#  'Accra': 10,
#  'Yuxi': 2,
#  'Anshun': 15,
#  'Vancouver': 7,
#  'Tangerang': 5,
#  'Konya': 13,
#  'Queens': 8,
#  'Yingkou': 13,
#  'Adana': 2,
#  'Medan': 10,
#  'Sanmenxia': 1,
#  'Indore': 13,
#  "Ma'anshan": 11,
#  'Pingliang': 4,
#  'Quzhou': 9,
#  'Baku': 3,
#  'Gaoping': 6,
#  'Huaibei': 14,
#  'Xining': 12,
#  'Harare': 1,
#  "Yan'an": 8,
#  'Havana': 6,
#  'Phnom Penh': 12,
#  'Fukuoka': 10,
#  'Mogadishu': 14,
#  'Jincheng': 3,
#  'Puning': 6,
#  'Lishui': 1,
#  'Qingyang': 4,
#  'Riverside': 5,
#  'Baltimore': 13,
#  'Haiphong': 8,
#  'Las Vegas': 3,
#  'Laibin': 12,
#  'Rawalpindi': 6,
#  'Kumasi': 6,
#  'Portland': 1,
#  'Vadodara': 6,
#  'Perth': 4,
#  'San Antonio': 8,
#  'Vishakhapatnam': 4,
#  'Gujranwala': 5,
#  'Gaziantep': 1,
#  'Fushun': 1,
#  'St. Louis': 6,
#  'Bamako': 5,
#  'Quito': 13,
#  'Minsk': 4,
#  'Pingxiang': 13,
#  'Chongzuo': 4,
#  'Sanliurfa': 10,
#  'Kananga': 6,
#  'Peshawar': 3,
#  'Sapporo': 8,
#  'Hezhou': 15,
#  'Jixi': 5,
#  'Caracas': 13,
#  'Fuxin': 1,
#  'Aleppo': 3,
#  'Almaty': 6,
#  'Dayr az Zawr': 1,
#  'Vienna': 5,
#  'Leeds': 4,
#  'Sacramento': 8,
#  'Blantyre': 1,
#  'Tainan': 5,
#  'Zhuhai': 8,
#  'Bucharest': 13,
#  'Wuwei': 7,
#  'Bhopal': 7,
#  'Multan': 11,
#  'Xiping': 13,
#  'Asuncion': 10,
#  'Saidu Sharif': 1,
#  'Hamburg': 12,
#  'Meru': 3}

# %%
destination_variables = LpVariable.dicts("Destination", destinations, lowBound=0, upBound=1, cat='Integer')

# %%
destination_variables
# Out:
# {'Tokyo': Destination_Tokyo,
#  'Jakarta': Destination_Jakarta,
#  'Delhi': Destination_Delhi,
#  'Mumbai': Destination_Mumbai,
#  'Manila': Destination_Manila,
#  'Shanghai': Destination_Shanghai,
#  'Sao Paulo': Destination_Sao_Paulo,
#  'Seoul': Destination_Seoul,
#  'Mexico City': Destination_Mexico_City,
#  'Guangzhou': Destination_Guangzhou,
#  'Beijing': Destination_Beijing,
#  'Cairo': Destination_Cairo,
#  'New York': Destination_New_York,
#  'Kolkata': Destination_Kolkata,
#  'Moscow': Destination_Moscow,
#  'Bangkok': Destination_Bangkok,
#  'Buenos Aires': Destination_Buenos_Aires,
#  'Shenzhen': Destination_Shenzhen,
#  'Dhaka': Destination_Dhaka,
#  'Lagos': Destination_Lagos,
#  'Istanbul': Destination_Istanbul,
#  'Osaka': Destination_Osaka,
#  'Karachi': Destination_Karachi,
#  'Bangalore': Destination_Bangalore,
#  'Tehran': Destination_Tehran,
#  'Kinshasa': Destination_Kinshasa,
#  'Ho Chi Minh City': Destination_Ho_Chi_Minh_City,
#  'Los Angeles': Destination_Los_Angeles,
#  'Rio de Janeiro': Destination_Rio_de_Janeiro,
#  'Nanyang': Destination_Nanyang,
#  'Baoding': Destination_Baoding,
#  'Chennai': Destination_Chennai,
#  'Chengdu': Destination_Chengdu,
#  'Lahore': Destination_Lahore,
#  'Paris': Destination_Paris,
#  'London': Destination_London,
#  'Linyi': Destination_Linyi,
#  'Tianjin': Destination_Tianjin,
#  'Shijiazhuang': Destination_Shijiazhuang,
#  'Zhoukou': Destination_Zhoukou,
#  'Lima': Destination_Lima,
#  'Hyderabad': Destination_Hyderabad,
#  'Handan': Destination_Handan,
#  'Bogota': Destination_Bogota,
#  'Weifang': Destination_Weifang,
#  'Nagoya': Destination_Nagoya,
#  'Wuhan': Destination_Wuhan,
#  'Heze': Destination_Heze,
#  'Ganzhou': Destination_Ganzhou,
#  'Tongshan': Destination_Tongshan,
#  'Chicago': Destination_Chicago,
#  'Luanda': Destination_Luanda,
#  'Changsha': Destination_Changsha,
#  'Fuyang': Destination_Fuyang,
#  'Kuala Lumpur': Destination_Kuala_Lumpur,
#  'Jining': Destination_Jining,
#  'Dongguan': Destination_Dongguan,
#  'Jinan': Destination_Jinan,
#  'Foshan': Destination_Foshan,
#  'Hanoi': Destination_Hanoi,
#  'Pune': Destination_Pune,
#  'Chongqing': Destination_Chongqing,
#  'Changchun': Destination_Changchun,
#  'Zhumadian': Destination_Zhumadian,
#  'Ningbo': Destination_Ningbo,
#  'Cangzhou': Destination_Cangzhou,
#  'Nanjing': Destination_Nanjing,
#  'Hefei': Destination_Hefei,
#  'Ahmedabad': Destination_Ahmedabad,
#  'Hong Kong': Destination_Hong_Kong,
#  'Zhanjiang': Destination_Zhanjiang,
#  'Shaoyang': Destination_Shaoyang,
#  'Hengyang': Destination_Hengyang,
#  'Khartoum': Destination_Khartoum,
#  'Nantong': Destination_Nantong,
#  'Yancheng': Destination_Yancheng,
#  'Nanning': Destination_Nanning,
#  "Xi'an": Destination_Xi'an,
#  'Shenyang': Destination_Shenyang,
#  'Tangshan': Destination_Tangshan,
#  'Santiago': Destination_Santiago,
#  'Zhengzhou': Destination_Zhengzhou,
#  'Shangqiu': Destination_Shangqiu,
#  'Yantai': Destination_Yantai,
#  'Riyadh': Destination_Riyadh,
#  'Dar es Salaam': Destination_Dar_es_Salaam,
#  'Xinyang': Destination_Xinyang,
#  'Shangrao': Destination_Shangrao,
#  'Luoyang': Destination_Luoyang,
#  'Bijie': Destination_Bijie,
#  'Quanzhou': Destination_Quanzhou,
#  'Hangzhou': Destination_Hangzhou,
#  'Miami': Destination_Miami,
#  'Huanggang': Destination_Huanggang,
#  'Maoming': Destination_Maoming,
#  'Kunming': Destination_Kunming,
#  'Nanchong': Destination_Nanchong,
#  'Zunyi': Destination_Zunyi,
#  'Jieyang': Destination_Jieyang,
#  "Lu'an": Destination_Lu'an,
#  'Yichun': Destination_Yichun,
#  'Madrid': Destination_Madrid,
#  'Changde': Destination_Changde,
#  'Taizhou': Destination_Taizhou,
#  'Liaocheng': Destination_Liaocheng,
#  'Qujing': Destination_Qujing,
#  'Surat': Destination_Surat,
#  'Baghdad': Destination_Baghdad,
#  'Qingdao': Destination_Qingdao,
#  'Singapore': Destination_Singapore,
#  'Dallas': Destination_Dallas,
#  'Dazhou': Destination_Dazhou,
#  'Suzhou': Destination_Suzhou,
#  'Xiangyang': Destination_Xiangyang,
#  'Philadelphia': Destination_Philadelphia,
#  'Giza': Destination_Giza,
#  'Nairobi': Destination_Nairobi,
#  'Nangandao': Destination_Nangandao,
#  'Ankara': Destination_Ankara,
#  "Tai'an": Destination_Tai'an,
#  'Yulin': Destination_Yulin,
#  'Dezhou': Destination_Dezhou,
#  'Houston': Destination_Houston,
#  'Atlanta': Destination_Atlanta,
#  'Yongzhou': Destination_Yongzhou,
#  'Rangoon': Destination_Rangoon,
#  'Toronto': Destination_Toronto,
#  'Suihua': Destination_Suihua,
#  'Washington': Destination_Washington,
#  'Qiqihar': Destination_Qiqihar,
#  'Jinhua': Destination_Jinhua,
#  'Saint Petersburg': Destination_Saint_Petersburg,
#  'Shantou': Destination_Shantou,
#  'Sydney': Destination_Sydney,
#  'Weinan': Destination_Weinan,
#  'Suqian': Destination_Suqian,
#  'Guadalajara': Destination_Guadalajara,
#  'Fuzhou': Destination_Fuzhou,
#  'Zhaotong': Destination_Zhaotong,
#  'Pudong': Destination_Pudong,
#  'Belo Horizonte': Destination_Belo_Horizonte,
#  'Zhangzhou': Destination_Zhangzhou,
#  'Bozhou': Destination_Bozhou,
#  'Melbourne': Destination_Melbourne,
#  'Nanchang': Destination_Nanchang,
#  'Xianyang': Destination_Xianyang,
#  'Surabaya': Destination_Surabaya,
#  'Abidjan': Destination_Abidjan,
#  'Huaihua': Destination_Huaihua,
#  "Ji'an": Destination_Ji'an,
#  'Mianyang': Destination_Mianyang,
#  'Xiaoganzhan': Destination_Xiaoganzhan,
#  'Shaoxing': Destination_Shaoxing,
#  'Alexandria': Destination_Alexandria,
#  'Yuncheng': Destination_Yuncheng,
#  'Pingdingshan': Destination_Pingdingshan,
#  'Huizhou': Destination_Huizhou,
#  "Huai'an": Destination_Huai'an,
#  'Xinpu': Destination_Xinpu,
#  'Chenzhou': Destination_Chenzhou,
#  'Guilin': Destination_Guilin,
#  'Jiujiang': Destination_Jiujiang,
#  'Anqing': Destination_Anqing,
#  'Boston': Destination_Boston,
#  'Huanglongsi': Destination_Huanglongsi,
#  'Jiangmen': Destination_Jiangmen,
#  'Changzhou': Destination_Changzhou,
#  'Barcelona': Destination_Barcelona,
#  'Wuxi': Destination_Wuxi,
#  'Zibo': Destination_Zibo,
#  'Jiaxing': Destination_Jiaxing,
#  'Dalian': Destination_Dalian,
#  'Hengshui': Destination_Hengshui,
#  'Harbin': Destination_Harbin,
#  'Yangzhou': Destination_Yangzhou,
#  'Yibin': Destination_Yibin,
#  'Johannesburg': Destination_Johannesburg,
#  'Yiyang': Destination_Yiyang,
#  'Meizhou': Destination_Meizhou,
#  'Chifeng': Destination_Chifeng,
#  'Casablanca': Destination_Casablanca,
#  'Guiyang': Destination_Guiyang,
#  'Langfang': Destination_Langfang,
#  'Zhangjiakou': Destination_Zhangjiakou,
#  'Izmir': Destination_Izmir,
#  'Linfen': Destination_Linfen,
#  'Wenzhou': Destination_Wenzhou,
#  'Monterrey': Destination_Monterrey,
#  'Luzhou': Destination_Luzhou,
#  'Jiangguanchi': Destination_Jiangguanchi,
#  'Neijiang': Destination_Neijiang,
#  'Phoenix': Destination_Phoenix,
#  'Yanjiang': Destination_Yanjiang,
#  'Zhaoqing': Destination_Zhaoqing,
#  'Xiaoxita': Destination_Xiaoxita,
#  'Guigang': Destination_Guigang,
#  'Xiamen': Destination_Xiamen,
#  'Chuzhou': Destination_Chuzhou,
#  'Zhuzhou': Destination_Zhuzhou,
#  'Amman': Destination_Amman,
#  'Jeddah': Destination_Jeddah,
#  'Loudi': Destination_Loudi,
#  'Deyang': Destination_Deyang,
#  'Qingyuan': Destination_Qingyuan,
#  'Wuhu': Destination_Wuhu,
#  'Hechi': Destination_Hechi,
#  'Seattle': Destination_Seattle,
#  'Binzhou': Destination_Binzhou,
#  'Yokohama': Destination_Yokohama,
#  'Liuzhou': Destination_Liuzhou,
#  'Baojishi': Destination_Baojishi,
#  "Guang'an": Destination_Guang'an,
#  'Hanzhong': Destination_Hanzhong,
#  'Kabul': Destination_Kabul,
#  'Zaozhuang': Destination_Zaozhuang,
#  'Berlin': Destination_Berlin,
#  'Anshan': Destination_Anshan,
#  'Lanzhou': Destination_Lanzhou,
#  'Chengde': Destination_Chengde,
#  'San Francisco': Destination_San_Francisco,
#  'Puyang': Destination_Puyang,
#  'Suining': Destination_Suining,
#  'Jiaozuo': Destination_Jiaozuo,
#  'Bengbu': Destination_Bengbu,
#  'Montreal': Destination_Montreal,
#  'Detroit': Destination_Detroit,
#  'Baicheng': Destination_Baicheng,
#  'Busan': Destination_Busan,
#  'Algiers': Destination_Algiers,
#  'Qincheng': Destination_Qincheng,
#  'Taiyuan': Destination_Taiyuan,
#  'Shiyan': Destination_Shiyan,
#  'Lucknow': Destination_Lucknow,
#  'Chaoyang': Destination_Chaoyang,
#  'Leshan': Destination_Leshan,
#  'Yulinshi': Destination_Yulinshi,
#  'Siping': Destination_Siping,
#  'Zhongshan': Destination_Zhongshan,
#  'Changzhi': Destination_Changzhi,
#  'San Diego': Destination_San_Diego,
#  'Faisalabad': Destination_Faisalabad,
#  'Santa Cruz': Destination_Santa_Cruz,
#  'Qinhuangdao': Destination_Qinhuangdao,
#  'Bazhou': Destination_Bazhou,
#  'Zhenjiang': Destination_Zhenjiang,
#  'Urumqi': Destination_Urumqi,
#  'Tongliao': Destination_Tongliao,
#  'Heyuan': Destination_Heyuan,
#  'Tongren': Destination_Tongren,
#  'Qinzhou': Destination_Qinzhou,
#  'Jaipur': Destination_Jaipur,
#  'Xinzhou': Destination_Xinzhou,
#  'Addis Ababa': Destination_Addis_Ababa,
#  'Meishan': Destination_Meishan,
#  'Brasilia': Destination_Brasilia,
#  'Mashhad': Destination_Mashhad,
#  'Jinzhou': Destination_Jinzhou,
#  'Tieling': Destination_Tieling,
#  'Shaoguan': Destination_Shaoguan,
#  'Kuwait City': Destination_Kuwait_City,
#  'Shanwei': Destination_Shanwei,
#  'Minneapolis': Destination_Minneapolis,
#  'Kyiv': Destination_Kyiv,
#  'Sanaa': Destination_Sanaa,
#  'Quezon City': Destination_Quezon_City,
#  'Dingxi': Destination_Dingxi,
#  'Incheon': Destination_Incheon,
#  'Bursa': Destination_Bursa,
#  'Ningde': Destination_Ningde,
#  'Tampa': Destination_Tampa,
#  'Daqing': Destination_Daqing,
#  'Birmingham': Destination_Birmingham,
#  'Putian': Destination_Putian,
#  'Huzhou': Destination_Huzhou,
#  'Salvador': Destination_Salvador,
#  'Wuzhou': Destination_Wuzhou,
#  'Xiangtan': Destination_Xiangtan,
#  'Denver': Destination_Denver,
#  'Rome': Destination_Rome,
#  'La Paz': Destination_La_Paz,
#  'Pyongyang': Destination_Pyongyang,
#  'Kano': Destination_Kano,
#  'Taichung': Destination_Taichung,
#  'Omdurman': Destination_Omdurman,
#  'Zigong': Destination_Zigong,
#  'Mudanjiang': Destination_Mudanjiang,
#  'Huludao': Destination_Huludao,
#  'Kaohsiung': Destination_Kaohsiung,
#  'Guayaquil': Destination_Guayaquil,
#  'Rizhao': Destination_Rizhao,
#  'Manchester': Destination_Manchester,
#  'Cawnpore': Destination_Cawnpore,
#  'Baotou': Destination_Baotou,
#  'Taipei': Destination_Taipei,
#  'Nanping': Destination_Nanping,
#  'Chaozhou': Destination_Chaozhou,
#  'Longyan': Destination_Longyan,
#  'Ibadan': Destination_Ibadan,
#  'Hohhot': Destination_Hohhot,
#  'Antananarivo': Destination_Antananarivo,
#  'Longba': Destination_Longba,
#  'Weihai': Destination_Weihai,
#  'Chattogram': Destination_Chattogram,
#  'Santo Domingo': Destination_Santo_Domingo,
#  'Xuanzhou': Destination_Xuanzhou,
#  'Sanming': Destination_Sanming,
#  'Brooklyn': Destination_Brooklyn,
#  'Yangjiang': Destination_Yangjiang,
#  'Medellin': Destination_Medellin,
#  'Yunfu': Destination_Yunfu,
#  'Brisbane': Destination_Brisbane,
#  'Baoshan': Destination_Baoshan,
#  'Dubai': Destination_Dubai,
#  'Luohe': Destination_Luohe,
#  'Qinbaling': Destination_Qinbaling,
#  'Mirzapur': Destination_Mirzapur,
#  'Guangyuan': Destination_Guangyuan,
#  'Cali': Destination_Cali,
#  'Huangshi': Destination_Huangshi,
#  'Daegu': Destination_Daegu,
#  'Fortaleza': Destination_Fortaleza,
#  'Guatemala City': Destination_Guatemala_City,
#  'Yaounde': Destination_Yaounde,
#  'Douala': Destination_Douala,
#  'Jilin': Destination_Jilin,
#  'Lianshan': Destination_Lianshan,
#  'Lincang': Destination_Lincang,
#  'Antalya': Destination_Antalya,
#  'Tashkent': Destination_Tashkent,
#  'Bandung': Destination_Bandung,
#  'Nagpur': Destination_Nagpur,
#  'Huainan': Destination_Huainan,
#  'Dandong': Destination_Dandong,
#  'Shangzhou': Destination_Shangzhou,
#  'Bekasi': Destination_Bekasi,
#  'Ghaziabad': Destination_Ghaziabad,
#  'Tijuana': Destination_Tijuana,
#  'Jiamusi': Destination_Jiamusi,
#  'Accra': Destination_Accra,
#  'Yuxi': Destination_Yuxi,
#  'Anshun': Destination_Anshun,
#  'Vancouver': Destination_Vancouver,
#  'Tangerang': Destination_Tangerang,
#  'Konya': Destination_Konya,
#  'Queens': Destination_Queens,
#  'Yingkou': Destination_Yingkou,
#  'Adana': Destination_Adana,
#  'Medan': Destination_Medan,
#  'Sanmenxia': Destination_Sanmenxia,
#  'Indore': Destination_Indore,
#  "Ma'anshan": Destination_Ma'anshan,
#  'Pingliang': Destination_Pingliang,
#  'Quzhou': Destination_Quzhou,
#  'Baku': Destination_Baku,
#  'Gaoping': Destination_Gaoping,
#  'Huaibei': Destination_Huaibei,
#  'Xining': Destination_Xining,
#  'Harare': Destination_Harare,
#  "Yan'an": Destination_Yan'an,
#  'Havana': Destination_Havana,
#  'Phnom Penh': Destination_Phnom_Penh,
#  'Fukuoka': Destination_Fukuoka,
#  'Mogadishu': Destination_Mogadishu,
#  'Jincheng': Destination_Jincheng,
#  'Puning': Destination_Puning,
#  'Lishui': Destination_Lishui,
#  'Qingyang': Destination_Qingyang,
#  'Riverside': Destination_Riverside,
#  'Baltimore': Destination_Baltimore,
#  'Haiphong': Destination_Haiphong,
#  'Las Vegas': Destination_Las_Vegas,
#  'Laibin': Destination_Laibin,
#  'Rawalpindi': Destination_Rawalpindi,
#  'Kumasi': Destination_Kumasi,
#  'Portland': Destination_Portland,
#  'Vadodara': Destination_Vadodara,
#  'Perth': Destination_Perth,
#  'San Antonio': Destination_San_Antonio,
#  'Vishakhapatnam': Destination_Vishakhapatnam,
#  'Gujranwala': Destination_Gujranwala,
#  'Gaziantep': Destination_Gaziantep,
#  'Fushun': Destination_Fushun,
#  'St. Louis': Destination_St._Louis,
#  'Bamako': Destination_Bamako,
#  'Quito': Destination_Quito,
#  'Minsk': Destination_Minsk,
#  'Pingxiang': Destination_Pingxiang,
#  'Chongzuo': Destination_Chongzuo,
#  'Sanliurfa': Destination_Sanliurfa,
#  'Kananga': Destination_Kananga,
#  'Peshawar': Destination_Peshawar,
#  'Sapporo': Destination_Sapporo,
#  'Hezhou': Destination_Hezhou,
#  'Jixi': Destination_Jixi,
#  'Caracas': Destination_Caracas,
#  'Fuxin': Destination_Fuxin,
#  'Aleppo': Destination_Aleppo,
#  'Almaty': Destination_Almaty,
#  'Dayr az Zawr': Destination_Dayr_az_Zawr,
#  'Vienna': Destination_Vienna,
#  'Leeds': Destination_Leeds,
#  'Sacramento': Destination_Sacramento,
#  'Blantyre': Destination_Blantyre,
#  'Tainan': Destination_Tainan,
#  'Zhuhai': Destination_Zhuhai,
#  'Bucharest': Destination_Bucharest,
#  'Wuwei': Destination_Wuwei,
#  'Bhopal': Destination_Bhopal,
#  'Multan': Destination_Multan,
#  'Xiping': Destination_Xiping,
#  'Asuncion': Destination_Asuncion,
#  'Saidu Sharif': Destination_Saidu_Sharif,
#  'Hamburg': Destination_Hamburg,
#  'Meru': Destination_Meru}

# %%
# Add objective function to the "prob" variable

objective_function = lpSum([costs[destination] * destination_variables[destination] for destination in destination_variables])

prob += objective_function

# %%
objective_function
# Out:
# 14772*Destination_Abidjan + 15165*Destination_Accra + 15603*Destination_Adana + 20092*Destination_Addis_Ababa + 11794*Destination_Ahmedabad + 16773*Destination_Aleppo + 11790*Destination_Alexandria + 9990*Destination_Algiers + 6261*Destination_Almaty + 13683*Destination_Amman + 1834*Destination_Ankara + 12112*Destination_Anqing + 9154*Destination_Anshan + 9504*Destination_Anshun + 7896*Destination_Antalya + 24386*Destination_Antananarivo + 14887*Destination_Asuncion + 9623*Destination_Atlanta + 2165*Destination_Baghdad + 22340*Destination_Baicheng + 20673*Destination_Baku + 3884*Destination_Baltimore + 19473*Destination_Bamako + 13210*Destination_Bandung + 2101*Destination_Bangalore + 8208*Destination_Bangkok + 23136*Destination_Baoding + 21404*Destination_Baojishi + 11817*Destination_Baoshan + 12491*Destination_Baotou + 10964*Destination_Barcelona + 3618*Destination_Bazhou + 1482*Destination_Beijing + 14272*Destination_Bekasi + 24913*Destination_Belo_Horizonte + 21657*Destination_Bengbu + 17121*Destination_Berlin + 19232*Destination_Bhopal + 23464*Destination_Bijie + 20435*Destination_Binzhou + 16750*Destination_Birmingham + 2659*Destination_Blantyre + 21036*Destination_Bogota + 8750*Destination_Boston + 17429*Destination_Bozhou + 5434*Destination_Brasilia + 19657*Destination_Brisbane + 8376*Destination_Brooklyn + 19771*Destination_Bucharest + 3044*Destination_Buenos_Aires + 5273*Destination_Bursa + 24180*Destination_Busan + 12532*Destination_Cairo + 12543*Destination_Cali + 21477*Destination_Cangzhou + 20014*Destination_Caracas + 11696*Destination_Casablanca + 3531*Destination_Cawnpore + 19118*Destination_Changchun + 7151*Destination_Changde + 10760*Destination_Changsha + 18769*Destination_Changzhi + 3430*Destination_Changzhou + 24966*Destination_Chaoyang + 6959*Destination_Chaozhou + 8014*Destination_Chattogram + 4199*Destination_Chengde + 21851*Destination_Chengdu + 21291*Destination_Chennai + 8744*Destination_Chenzhou + 18629*Destination_Chicago + 6506*Destination_Chifeng + 15552*Destination_Chongqing + 8404*Destination_Chongzuo + 1826*Destination_Chuzhou + 13807*Destination_Daegu + 2501*Destination_Dalian + 12845*Destination_Dallas + 4840*Destination_Dandong + 14594*Destination_Daqing + 15062*Destination_Dar_es_Salaam + 4185*Destination_Dayr_az_Zawr + 24784*Destination_Dazhou + 4078*Destination_Delhi + 4045*Destination_Denver + 13111*Destination_Detroit + 17353*Destination_Deyang + 9743*Destination_Dezhou + 10902*Destination_Dhaka + 3687*Destination_Dingxi + 17840*Destination_Dongguan + 7530*Destination_Douala + 6566*Destination_Dubai + 21434*Destination_Faisalabad + 16371*Destination_Fortaleza + 9919*Destination_Foshan + 20089*Destination_Fukuoka + 10642*Destination_Fushun + 18486*Destination_Fuxin + 9519*Destination_Fuyang + 7631*Destination_Fuzhou + 18963*Destination_Ganzhou + 5689*Destination_Gaoping + 22850*Destination_Gaziantep + 21774*Destination_Ghaziabad + 4932*Destination_Giza + 9517*Destination_Guadalajara + 5652*Destination_Guang'an + 5563*Destination_Guangyuan + 23861*Destination_Guangzhou + 22587*Destination_Guatemala_City + 12681*Destination_Guayaquil + 16803*Destination_Guigang + 19576*Destination_Guilin + 24660*Destination_Guiyang + 4453*Destination_Gujranwala + 15451*Destination_Haiphong + 13070*Destination_Hamburg + 2964*Destination_Handan + 24055*Destination_Hangzhou + 15885*Destination_Hanoi + 5965*Destination_Hanzhong + 5356*Destination_Harare + 8054*Destination_Harbin + 20105*Destination_Havana + 6469*Destination_Hechi + 21043*Destination_Hefei + 24148*Destination_Hengshui + 5824*Destination_Hengyang + 2397*Destination_Heyuan + 3206*Destination_Heze + 5610*Destination_Hezhou + 10011*Destination_Ho_Chi_Minh_City + 12616*Destination_Hohhot + 6783*Destination_Hong_Kong + 24689*Destination_Houston + 14779*Destination_Huai'an + 7244*Destination_Huaibei + 24735*Destination_Huaihua + 16168*Destination_Huainan + 24829*Destination_Huanggang + 12630*Destination_Huanglongsi + 19161*Destination_Huangshi + 1829 ...

# %%
# Add restrictions to the "prob" variable

restriction1 =  lpSum([durations[destination] * destination_variables[destination] for destination in destination_variables]) == total_vacations_days
# Example of additional restriction: have to stay less than 20 days in Mumbai
restriction2 =  lpSum(durations['Mumbai'] * destination_variables['Mumbai']) <= 20

prob += restriction1
prob += restriction2

# %%
restriction1
# Out:
# 8*Destination_Abidjan + 10*Destination_Accra + 2*Destination_Adana + 5*Destination_Addis_Ababa + 2*Destination_Ahmedabad + 3*Destination_Aleppo + 5*Destination_Alexandria + 1*Destination_Algiers + 6*Destination_Almaty + 14*Destination_Amman + 4*Destination_Ankara + 3*Destination_Anqing + 11*Destination_Anshan + 15*Destination_Anshun + 5*Destination_Antalya + 8*Destination_Antananarivo + 10*Destination_Asuncion + 12*Destination_Atlanta + 7*Destination_Baghdad + 4*Destination_Baicheng + 3*Destination_Baku + 13*Destination_Baltimore + 5*Destination_Bamako + 9*Destination_Bandung + 1*Destination_Bangalore + 7*Destination_Bangkok + 15*Destination_Baoding + 2*Destination_Baojishi + 8*Destination_Baoshan + 7*Destination_Baotou + 9*Destination_Barcelona + 11*Destination_Bazhou + 12*Destination_Beijing + 4*Destination_Bekasi + 2*Destination_Belo_Horizonte + 5*Destination_Bengbu + 6*Destination_Berlin + 7*Destination_Bhopal + 5*Destination_Bijie + 6*Destination_Binzhou + 12*Destination_Birmingham + 1*Destination_Blantyre + 4*Destination_Bogota + 11*Destination_Boston + 10*Destination_Bozhou + 4*Destination_Brasilia + 4*Destination_Brisbane + 7*Destination_Brooklyn + 13*Destination_Bucharest + 5*Destination_Buenos_Aires + 10*Destination_Bursa + 11*Destination_Busan + 6*Destination_Cairo + 8*Destination_Cali + 8*Destination_Cangzhou + 13*Destination_Caracas + 5*Destination_Casablanca + 8*Destination_Cawnpore + 11*Destination_Changchun + 11*Destination_Changde + 7*Destination_Changsha + 13*Destination_Changzhi + 6*Destination_Changzhou + 7*Destination_Chaoyang + 7*Destination_Chaozhou + 10*Destination_Chattogram + 13*Destination_Chengde + 15*Destination_Chengdu + 12*Destination_Chennai + 3*Destination_Chenzhou + 3*Destination_Chicago + 8*Destination_Chifeng + 13*Destination_Chongqing + 4*Destination_Chongzuo + 15*Destination_Chuzhou + 3*Destination_Daegu + 1*Destination_Dalian + 7*Destination_Dallas + 6*Destination_Dandong + 7*Destination_Daqing + 15*Destination_Dar_es_Salaam + 1*Destination_Dayr_az_Zawr + 13*Destination_Dazhou + 1*Destination_Delhi + 3*Destination_Denver + 6*Destination_Detroit + 2*Destination_Deyang + 6*Destination_Dezhou + 3*Destination_Dhaka + 6*Destination_Dingxi + 11*Destination_Dongguan + 4*Destination_Douala + 6*Destination_Dubai + 12*Destination_Faisalabad + 10*Destination_Fortaleza + 6*Destination_Foshan + 10*Destination_Fukuoka + 1*Destination_Fushun + 1*Destination_Fuxin + 7*Destination_Fuyang + 8*Destination_Fuzhou + 2*Destination_Ganzhou + 6*Destination_Gaoping + 1*Destination_Gaziantep + 1*Destination_Ghaziabad + 1*Destination_Giza + 12*Destination_Guadalajara + 10*Destination_Guang'an + 3*Destination_Guangyuan + 2*Destination_Guangzhou + 15*Destination_Guatemala_City + 8*Destination_Guayaquil + 8*Destination_Guigang + 4*Destination_Guilin + 12*Destination_Guiyang + 5*Destination_Gujranwala + 8*Destination_Haiphong + 12*Destination_Hamburg + 1*Destination_Handan + 3*Destination_Hangzhou + 3*Destination_Hanoi + 12*Destination_Hanzhong + 1*Destination_Harare + 13*Destination_Harbin + 6*Destination_Havana + 14*Destination_Hechi + 11*Destination_Hefei + 2*Destination_Hengshui + 3*Destination_Hengyang + 7*Destination_Heyuan + 5*Destination_Heze + 15*Destination_Hezhou + 6*Destination_Ho_Chi_Minh_City + 8*Destination_Hohhot + 13*Destination_Hong_Kong + 12*Destination_Houston + 4*Destination_Huai'an + 14*Destination_Huaibei + 1*Destination_Huaihua + 12*Destination_Huainan + 12*Destination_Huanggang + 2*Destination_Huanglongsi + 3*Destination_Huangshi + 7*Destination_Huizhou + 9*Destination_Huludao + 12*Destination_Huzhou + 6*Destination_Hyderabad + 6*Destination_Ibadan + 2*Destination_Incheon + 13*Destination_Indore + 13*Destination_Istanbul + 12*Destination_Izmir + 4*Destination_Jaipur + 7*Destination_Jakarta + 2*Destination_Jeddah + 2*Destination_Ji'an + 5*Destination_Jiamusi + 6*Destination_Jiangguanchi + 6*Destination_Jiangmen + 13*Destination_Jiaozuo + 1*Destination_Jiaxing + 5*Destination_Jieyang + 6*Destinat ...

# %%
restriction2
# Out:
# 7*Destination_Mumbai + -20 <= 0

# %%
prob.solve()
print("Solution status: {}".format(LpStatus[prob.status]))
# Out:
# Solution status: Optimal

# %%
selected_destinations = []

variables_mapping = {str(value): key for (key, value) in destination_variables.items()}

for variable in prob.variables():
    if variable.varValue == 1:
        selected_destinations.append(variables_mapping[variable.name])

print('Selected destinations: \n')
for destination in selected_destinations:
    print(destination)
    print('Cost (USD):', costs[destination])
    print('Duration (days):', durations[destination], '\n')
# Out:
# Selected destinations:
#
# Monterrey
# Cost (USD): 1378
# Duration (days): 15
#
# Suining
# Cost (USD): 1065
# Duration (days): 5
